# %%
import numpy as np
import pandas as pd

import plotly
import plotly.plotly as py
import plotly.graph_objs as go
plotly.tools.set_credentials_file(username='remoras2', api_key='JqXPI9S2Fs9rHbqFMEcr')
mapbox_access_token = 'pk.eyJ1IjoicmVtb3JhczIiLCJhIjoiY2plYnl0ODczMGlpOTJ3czN0bGVoMG1qdSJ9.yJz5d8RD3xPpafPG2PAnVg'

# %%
def read_data(filename):
    df = pd.read_csv(filename)
    return df

# %%
CT = read_data('2017_smd_hourly_CT.csv')
ME = read_data('2017_smd_hourly_ME.csv')
NEMA = read_data('2017_smd_hourly_NEMA.csv')
NH = read_data('2017_smd_hourly_NH.csv')
RI = read_data('2017_smd_hourly_RI.csv')
SEMA = read_data('2017_smd_hourly_SEMA.csv')
VT = read_data('2017_smd_hourly_VT.csv')
WCMA = read_data('2017_smd_hourly_WCMA.csv')
files=[CT,ME,NEMA,NH,RI,SEMA,VT,WCMA]

# %%
for x in files:
    print(x.describe())
# Out:
#             Hr_End       DA_LMP        DA_EC        DA_CC       DA_MLC  \
# count  8760.000000  8760.000000  8760.000000  8760.000000  8760.000000
# mean     12.500000    33.356939    33.247715     0.057965     0.051263
# std       6.922582    21.323825    21.615558     1.096482     0.538804
# min       1.000000     1.020000     1.020000   -13.230000    -5.600000
# 25%       6.750000    21.720000    21.517500     0.000000    -0.050000
# 50%      12.500000    28.065000    27.930000     0.000000     0.130000
# 75%      18.250000    37.400000    37.160000     0.020000     0.290000
# max      24.000000   225.720000   230.340000    42.110000     1.840000
#
#             RT_LMP        RT_EC        RT_CC       RT_MLC  Dry_Bulb  Dew_Point
# count  8760.000000  8760.000000  8760.000000  8760.000000       0.0        0.0
# mean     33.933292    33.730473     0.070468     0.132353       NaN        NaN
# std      30.665054    31.008651     2.436028     0.578701       NaN        NaN
# ...

# %%
data = go.Data([
    go.Scattermapbox(
        lat=[41.8],
        lon=[-71.4],
        mode='markers',
        marker=go.Marker(
            size=18,
            color='rgb(255, 0, 225)',
            opacity=0.7
        ),
        text='Providence,RI',
        hoverinfo='text'
    ),
    go.Scattermapbox(
        lat=[41.1],
        lon=[-73.2],
        mode='markers',
        marker=go.Marker(
            size=18,
            color='rgb(255, 0, 225)'
        ),
        text='Bridgeport, CT',
        hoverinfo='text'
    ),
    go.Scattermapbox(
        lat=[42.4],
        lon=[-71.0],
        mode='markers',
        marker=go.Marker(
            size=18,
            color='rgb(255, 0, 225)'
        ),
        text='Boston, MA',
        hoverinfo='text'
    ),
    go.Scattermapbox(
        lat=[44.5],
        lon=[-73.2],
        mode='markers',
        marker=go.Marker(
            size=18,
            color='rgb(255, 0, 225)'
        ),
        text='Burlington, VT',
        hoverinfo='text'
    ),
    go.Scattermapbox(
        lat=[43.2],
        lon=[-71.5],
        mode='markers',
        marker=go.Marker(
            size=18,
            color='rgb(255, 0, 225)'
        ),
        text='Concord, NH',
        hoverinfo='text'
    ),
    go.Scattermapbox(
        lat=[43.7],
        lon=[-70.2],
        mode='markers',
        marker=go.Marker(
            size=18,
            color='rgb(255, 0, 225)'
        ),
        text='Portland, ME',
        hoverinfo='text'
    ),
    go.Scattermapbox(
        lat=[42.9],
        lon=[-72.6],
        mode='markers',
        marker=go.Marker(
            size=18,
            color='rgb(255, 0, 225)'
        ),
        text='Windsor Locks, CT',
        hoverinfo='text'
    ),
    go.Scattermapbox(
        lat=[42.3],
        lon=[-71.8],
        mode='markers',
        marker=go.Marker(
            size=18,
            color='rgb(255, 0, 225)'
        ),
        text='Worcester, MA',
        hoverinfo='text'
    )]
)

layout = go.Layout(
    title='ISO data',
    autosize=True,
    hovermode='closest',
    showlegend=False,
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=42.8,
            lon=-71.4
        ),
        pitch=0,
        zoom=5,
    ),
)

# %%
fig = dict(data=data, layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~remoras2/13.embed" height="525px" width="100%"></iframe>
